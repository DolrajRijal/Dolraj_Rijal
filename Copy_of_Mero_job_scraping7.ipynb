# %% [markdown]
# <a href="https://colab.research.google.com/github/DolrajRijal/Python-Projects/blob/main/Copy_of_Mero_job_scraping7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries requests to get response and bs4 for parsing and scraping

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Use get function of requests

# %%
r = requests.get("https://merojob.com/")

# %% [markdown]
# Now make soup object using beautifulsoup and parsing the website with html parser

# %%
Soup = BeautifulSoup(r.content,"html.parser")
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title> Search Jobs in Nepal - Job Vacancies in Nepal | merojob </title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="Find most recent jobs in Nepal at merojob. We offer career opportunities &amp; advice for job seekers and hiring &amp; recruitment services for organization. " name="description">
# <meta content="merojob.com, jobs in Nepal, jobsite in Nepal, job vacancies in Nepal, job vacancy in Nepal, job site in Nepal recent job vacancies in Nepal, job opportunities in Nepal, job sites in Nepal, find jobs in Nepal, find jobs in Nepal, job search in Nepal, job search. " name="keywords">
# <meta content="  merojob.com  " name="author">
# <link href="https://merojob.com" rel="canonical"/>
# <meta content="Search Jobs in Nepal - Job Vacancies in Nepal | merojob" property="og:title"/>
# <meta content="https://static.merojob.com/images/logo/logo-og-image.jpg" property="og:image"/>
# <meta content="Find most recent jobs in Nepal at merojob. We offer career opportunities &amp; advice for job seekers and hiring &amp; recruitment services for organization." property="og:description"/>
# <meta content="https://merojob.com/" property="og:url"/>
# <meta content="website" property="og:type">
# <meta content="230516776988241" property="fb:app_id"/>
# <meta content="#002A5B" name="theme-color"/>
# <meta content="KVzb1w4KL9v9xYDmCb-NYo9d0jRnm4e4cirTwVM9lfY" name="google-site-verification">
# <meta content="fs011kpc1knfbldfrttg52amlp4tf4" name="facebook-domain-verification"/>
# <link href="https://static.merojob.com/images/mj-logo.png" rel="shortcut icon" type="image/png"/>
# <link href="https://static.merojob.com/dist/main.4fb3c46a2616c83d69c9.bundle.css" rel="stylesheet" type="text/css"/>
# <link href="https://static.merojob.com/manifest.json" rel="manifest"/>
# <script defer="">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-WX6WP4');</script>
# <script defer="">
#       window.googletag = window.googletag || {cmd: []};
#       googletag.cmd.push(function() {
#         var mapping = googletag.sizeMapping().
#                 addSize([320, 400], [320, 100]).                         // Accepts both common mobile banner formats
#                 addSize([360, 640], [320, 100]).                        // Same width as mapping above, more available height
#                 addSize([750, 200], [728, 90]).                         // Landscape tablet
#                 addSize([1050, 200], [728, 90]).build();                // Desktop
#
#        // Define the GPT slot
#         googletag.defineSlot('/35754210/MJ_CB_TOP', [[728, 90],[320, 100]], 'div-gpt-ad-1664107433705-0').defineSizeMapping(mapping).addService(googletag.pubads());
#         googletag.defineSlot('/35754210/MJ_HP_CB1', [[728, 90],[320, 100]], 'div-gpt-ad-1578459468407-0').defineSizeMapping(mapping).addService(googletag.pubads());
#         googletag.defineSlot('/35754210/MJ-HP_CB2', [[728, 90],[320, 100]], 'div-gpt-ad-1578460198260-0').defineSizeMapping(mapping).addService(googletag.pubads());
#
#         googletag.defineSlot('/35754210/MJ_HP_TBR1', [270,82], 'div-gpt-ad-1578475782547-0').addService(googletag.pubads());
#         googletag.defineSlot('/35754210/MJ_HP_TBR2', [270,150], 'div-gpt-ad-1578480082036-0').addService(googletag.pubads());
#         googletag.defineSlot('/35754210/MJ_HP_TBR3', [270,150], 'div-gpt-ad-1578480154188-0').addService(googletag.pubads());
#         googletag.defineSlot('/35754210/MJ_HP_TBR4', [270,150], 'div-gpt-ad-1578480233430-0').addService(googletag.pubads());
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#
#         // Start ad fetching
#         googletag.enableServices();
#       });
#     </script>
# </meta></meta></meta></meta></meta></head>
# <body>
# <div class="notify"></div>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#       var size_map = googletag.sizeMapping().
#       addSize([300, 200], [320, 60]).                           // Accepts both common mobile banner formats
#           addSize([680, 200], [728, 60]).                        // Landscape tablet
#           addSize([800, 200], [1024, 60]).                      // Desktop
#           addSize([1300, 200], [1410, 60]).build();              // Large Screen
#
#     googletag.defineSlot('/35754210/MJ_NAV', [[1410, 60],[1024, 60],[728, 60],[320, 60]], 'div-gpt-ad-1604299751568-0').defineSizeMapping(size_map).addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#     googletag.pubads().collapseEmptyDivs();
#     googletag.pubads().addEventListener('slotOnload', function(event) {
#       if (event.slot.getSlotElementId() === "div-gpt-ad-1604299751568-0") {
#         let oneHourMs = 60 * 60 * 1000;
#         let currentTimestamp = Date.now();
#         let lastTimestamp = Number(localStorage.getItem("last-showed-at"));
#         if ((currentTimestamp - lastTimestamp) >= oneHourMs || lastTimestamp === 0) {
#             $("#nav-ad").removeClass('d-none');
#         }else{
#             $("#nav-ad").addClass('d-none');
#         }
#       }
#     });
#   });
# </script>
# <div class="card d-none" id="nav-ad">
# <div class="text-center height-60 overflow-hidden" id="div-gpt-ad-1604299751568-0">
# <script>
#             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1604299751568-0'); });
#         </script>
# </div>
# <button aria-label="Close" class="close close-ad position-absolute mt-3" id="close-nav-ad" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <header class="bg-white border-bottom d-none d-md-block d-lg-block">
# <div class="container clearfix">
# <ul class="nav nav-pills float-left small">
# <li class="nav-item">
# <a class="nav-link text-muted " href="/search/" target="_blank">
# SEARCH JOB
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-muted " href="/blog/" target="_blank">
# BLOG
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-muted " href="/contact/" target="_blank">
# CONTACT
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-muted " href="/faq/" target="_blank">
# FAQ
# </a>
# </li>
# </ul>
# <ul class="nav nav-pills float-right small">
# <li class="nav-item dropdown ">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link custom-login-nav dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="icon-password"></span> LOGIN
# </a>
# <div class="dropdown-menu dropdown-menu-right p-3 fixed-width-300 right" id="custom-login">
# <ul class="nav nav-tabs" id="CustomLoginBlock" role="tablist">
# <li class="nav-item">
# <a class="nav-link active" data-loginurl="/jobseeker/login/" data-toggle="tab" href="#jobseeker" role="tab">Jobseeker</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-loginurl="/employer/login/" data-toggle="tab" href="#employer" role="tab">Employer</a>
# </li>
# </ul>
# <div class="tab-content">
# <form action="/jobseeker/login/" id="CustomLoginForm" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="kviQljWGecejyqCd5muc7mElPYNDtA46tfCfpEeRiXmtIde2p8rP8FmzFtGvEKtA"/>
# <div class="mt-2 mb-1">
# <small class="text-muted">
# Login with your registered Email &amp; Password.
# </small>
# </div>
# <div class="form-group" id="div_id_login">
# <div class="">
# <input autocomplete="email" class="textinput textInput form-control" id="id_login" name="login" placeholder="E-mail address" required="" type="email"/>
# </div>
# </div>
# <div class="form-group" id="div_id_password">
# <div class="">
# <input autocomplete="current-password" class="textinput textInput form-control" id="id_password" name="password" placeholder="Password" required="" type="password"/>
# </div>
# </div>
# <div>
# <div class="float-left login-modal">
# <div class="form-group">
# <div class="form-check" id="div_id_remember">
# <label class="form-check-label" for="id_remember">
# <input class="checkboxinput form-check-input" id="id_remember" name="remember" type="checkbox"/>
# Remember Me
# </label>
# </div>
# </div>
# </div>
# <div class="float-right">
# <a href="/reset/password/">Forgot Password?</a>
# </div>
# </div>
# <div id="CustomLoginJs">
# <div class="clearfix"></div>
# <div class="text-center">
# <button class="btn btn-md bg-secondary text-white w-50" type="submit">Log
# in
# </button>
# </div>
# <div class="dropdown-divider"></div>
# <div class="text-center">
# <span><strong>Don't have an account?</strong></span>
# <a href="/jobseeker/register/">
# Register Now
# </a>
# </div>
# <div class="dropdown-divider"></div>
# <div class="text-center">
# <p class="mb-1 font-weight-bold">Or</p>
# Log in with:
# <a class="btn-google" href="/google/login/?method=oauth2">
# <span class="icon-googleplus google-ico"></span>
# </a>
# </div>
# </div>
# <div id="CustomLoginEmp">
# <div class="clearfix"></div>
# <div class="text-center">
# <button class="btn btn-primary btn-md w-50" type="submit">Log in</button>
# </div>
# <div class="dropdown-divider"></div>
# <div class="text-center">
# <span><strong>Don't have an account?</strong></span>
# <a href="/employer/register/">
# Register Now
# </a>
# </div>
# </div>
# </form>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown ">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link custom-register-nav dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="icon-user"></span> REGISTER
# </a>
# <div class="dropdown-menu dropdown-menu-right p-3 fixed-width-300" id="custom-signup">
# <ul class="nav nav-tabs" role="tablist">
# <li class="nav-item">
# <a class="nav-link active" data-toggle="tab" href="#jobseeker_register" role="tab">Jobseeker</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-toggle="tab" href="#employer_register" role="tab">Employer</a>
# </li>
# </ul>
# <div class="tab-content text-center">
# <div class="tab-pane active" id="jobseeker_register" role="tabpanel">
# <div class="m-2 p-2">
# <span class="icon-user display-4"></span>
# <div class="mt-2">
# <a class="btn bg-secondary text-white w-50" href="/jobseeker/register/">Register</a>
# </div>
# </div>
# <div class="dropdown-divider my-2 p-0"></div>
# <div>Create a free account to apply for jobs</div>
# </div>
# <div class="tab-pane" id="employer_register" role="tabpanel">
# <div class="m-2 p-2">
# <span class="icon-building display-4"></span>
# <div class="mt-2">
# <a class="btn bg-primary text-white w-50" href="/employer/register/">Register</a>
# </div>
# </div>
# <div class="dropdown-divider my-2 p-0"></div>
# <div>Create free account to post vacancy</div>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link active" href="/employer-zone/">
# <span class="icon-building mr-1"></span> EMPLOYER ZONE
# </a>
# </li>
# </ul>
# </div>
# </header>
# <div class="shadow-sm sticky-top navbar-expand-md shadow-sm sticky-top navbar-light bg-white" id="navigation">
# <div class="container">
# <div class="row align-items-center">
# <div class="col-md-2">
# <div id="navbar-fixed-top">
# <a href="/">
# <img alt="merojob" class="py-2 brand-logo-w my-0 mx-2" height="55" src="https://static.merojob.com/images/logo/svg/mj_logo.svg" width="150"/>
# </a>
# <button class="navbar-toggler float-right m-2 clearfix" data-target="#collapsibleNavbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon text-secondary"></span>
# </button>
# </div>
# </div>
# <div class="col-md-1"></div>
# <div class="col-md-9">
# <div class="collapse navbar-collapse justify-content-end" id="collapsibleNavbar">
# <div class="d-flex flex-row justify-content-center d-md-none">
# <ul class="nav nav-pills float-right small">
# <li class="nav-item dropdown ">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link custom-login-nav dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="icon-password"></span> LOGIN
# </a>
# <div class="dropdown-menu dropdown-menu-right ml-4 p-3 fixed-width-300 center" id="custom-login">
# <ul class="nav nav-tabs" id="CustomLoginBlock" role="tablist">
# <li class="nav-item">
# <a class="nav-link active" data-loginurl="/jobseeker/login/" data-toggle="tab" href="#jobseeker" role="tab">Jobseeker</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-loginurl="/employer/login/" data-toggle="tab" href="#employer" role="tab">Employer</a>
# </li>
# </ul>
# <div class="tab-content">
# <form action="/jobseeker/login/" id="CustomLoginForm" method="post">
# <input name="csrfmiddlewaretoken" type="hidden" value="kviQljWGecejyqCd5muc7mElPYNDtA46tfCfpEeRiXmtIde2p8rP8FmzFtGvEKtA"/>
# <div class="mt-2 mb-1">
# <small class="text-muted">
# Login with your registered Email &amp; Password.
# </small>
# </div>
# <div class="form-group" id="div_id_login">
# <div class="">
# <input autocomplete="email" class="textinput textInput form-control" id="id_login" name="login" placeholder="E-mail address" required="" type="email"/>
# </div>
# </div>
# <div class="form-group" id="div_id_password">
# <div class="">
# <input autocomplete="current-password" class="textinput textInput form-control" id="id_password" name="password" placeholder="Password" required="" type="password"/>
# </div>
# </div>
# <div>
# <div class="float-left login-modal">
# <div class="form-group">
# <div class="form-check" id="div_id_remember">
# <label class="form-check-label" for="id_remember">
# <input class="checkboxinput form-check-input" id="id_remember" name="remember" type="checkbox"/>
# Remember Me
# </label>
# </div>
# </div>
# </div>
# <div class="float-right">
# <a href="/reset/password/">Forgot Password?</a>
# </div>
# </div>
# <div id="CustomLoginJs">
# <div class="clearfix"></div>
# <div class="text-center">
# <button class="btn btn-md bg-secondary text-white w-50" type="submit">Log
# in
# </button>
# </div>
# <div class="dropdown-divider"></div>
# <div class="text-center">
# <span><strong>Don't have an account?</strong></span>
# <a href="/jobseeker/register/">
# Register Now
# </a>
# </div>
# <div class="dropdown-divider"></div>
# <div class="text-center">
# <p class="mb-1 font-weight-bold">Or</p>
# Log in with:
# <a href="/google/login/?method=oauth2">
# <span class="icon-googleplus google-ico"></span>
# </a>
# </div>
# </div>
# </form>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown ">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link custom-register-nav dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="icon-user"></span> REGISTER
# </a>
# <div class="dropdown-menu dropdown-menu-right ml-4 p-3 fixed-width-300" id="custom-signup">
# <ul class="nav nav-tabs" role="tablist">
# <li class="nav-item">
# <a class="nav-link active" data-toggle="tab" href="#jobseeker_register" role="tab">Jobseeker</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-toggle="tab" href="#employer_register" role="tab">Employer</a>
# </li>
# </ul>
# <div class="tab-content text-center">
# <div class="tab-pane active" id="jobseeker_register" role="tabpanel">
# <div class="m-2 p-2">
# <span class="icon-user display-4"></span>
# <div class="mt-2">
# <a class="btn bg-secondary text-white w-50" href="/jobseeker/register/">Register</a>
# </div>
# </div>
# <div class="dropdown-divider my-2 p-0"></div>
# <div>Create a free account to apply for jobs</div>
# </div>
# <div class="tab-pane" id="employer_register" role="tabpanel">
# <div class="m-2 p-2">
# <span class="icon-building display-4"></span>
# <div class="mt-2">
# <a class="btn bg-primary text-white w-50" href="/employer/register/">Register</a>
# </div>
# </div>
# <div class="dropdown-divider my-2 p-0"></div>
# <div>Create free account to post vacancy</div>
# </div>
# </div>
# </div>
# </li>
# <li class="_he-item">
# <a class="nav-link" href="/employer-zone/">
# <span class="icon-building mr-1"></span> EMPLOYER ZONE
# </a>
# </li>
# </ul>
# </div>
# <ul class="navbar-nav mx-4 d-md-none text-muted">
# <li class="nav-item">
# <a class="nav-link " href="/search/">
# SEARCH JOB
#  </a>
# </li>
# <li class="nav-item">
# <a class="nav-link " href="/blog/">
# BLOG
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link " href="/contact/">
# CONTACT
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link " href="/faq/">
# FAQ
# </a>
# </li>
# </ul>
# </div>
# <div class="d-flex flex-row justify-content-md-end justify-content-center d-none d-md-block">
# <div class="p-2 mx-1 mt-md-2 text-center">
# </div>
# <div class="py-2 px-0 mt-md-2 text-center d-none d-md-block">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="bg-default-img img-fluid">
# <div class="container">
# <div class="row">
# <div class="col-md-8 my-auto pt-2">
# <img src="https://static.merojob.com/images/default_pp/header-image.png" width="100%"/>
# <form action="/search/" class="bg-dgray-o p-2" method="GET">
# <div class="col-md-12 col-12 col-sm-12 m-0 p-0">
# <div class="tab-content">
# <div class="input-group">
# <input aria-label="Search by Job Title" class="form-control" data-provide="typeahead" id="job_related:job_search" name="q" placeholder="Search by Job Title" type="text" value=""/>
# <span class="input-group-append">
# <button class="btn btn-success text-white" id="search-button" type="submit">
# <span id="search_icon"><span class="icon-search mr-1"></span></span>
# <span id="search_text"> SEARCH JOBS</span>
# </button>
# </span>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="col-md-1">
# </div>
# <div class="col-md-3 text-center text-md-left pl-md-0">
# <div class="bg-dgray-o">
# <div class="px-1 py-2 text-white">
# <div class="py-3">
# <h5 class="py-2 mb-0">
# <span class="py-2">WHO UNDERSTANDS<br/>IT'S PERSONAL?</span>
# <br/>WE DO.<br/><br/>
# <span>TO US,<br/>IT'S ABOUT YOU</span>
# </h5>
# <h5>
# <small>Search, Apply &amp; Get Jobs in Nepal - Free</small>
# </h5>
# </div>
# </div>
# <div class="p-2"></div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="container">
# <div class="row mb-3">
# <div class="col-md-9">
# <div class="row jobs">
# <div class="col-md-12">
# <div class="card text-center mt-3 height-overflow-x" id="div-gpt-ad-1664107433705-0">
# <script>
#                             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1664107433705-0'); });
#                         </script>
# </div>
# <section class="mt-3">
# <div class="card">
# <div class="card-header" itemtype="http://schema.org/Service">
# <h1 class="h6 mb-0" itemprop="name">
# <span class="icon-top-job mr-1 text-success"></span>
# <strong>Top Jobs</strong></h1>
# </div>
# <div class="card-body p-0">
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class="has-multiple p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Euro School" itemprop="name"/>
# <img alt="Euro School" class="d-flex lazy" data-original="/media/cache/54/fe/54fe4fdf0d7447f0cce66cf0892ab91c.jpg" height="60" itemprop="image" width="60">
# </img></div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Euro School
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/it-technician-39/" title="IT Technician - Apply Before: 1 week, 4 days from now">
# <span itemprop="title">
# IT Technician
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Ensure smoo…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/guitar-teacher/" title="Guitar Teacher - Apply Before: 1 week, 4 days from now">
# <span itemprop="title">
# Guitar Teacher
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;&lt;span&gt;Demon…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 job-list d-none">
# •
# <a class="job_title hover-primary" href="/food-and-dining-supervisor/" title="Food and Dining Supervisor - Apply Before: 1 week, 4 days from now">
# <span itemprop="title">
# Food and Dining Supervisor
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Training, a…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# <div class="absolute-dropdown">
# <span class="float-right"><span class="icon-arrow-down job-card-dropdown"></span></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Cedar Gate Services" itemprop="name"/>
# <img alt="Cedar Gate Services" class="d-flex lazy" data-original="/media/cache/52/cb/52cb8c4b28d9890c98644244722f3dc2.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Cedar Gate Services
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/billing-specialist-2/" title="Billing Specialist - Apply Before: 2 weeks, 1 day from now">
# <span itemprop="title">
# Billing Specialist
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;p&gt;Cedar Gate Servi…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Nepal Liquors" itemprop="name"/>
# <img alt="Nepal Liquors" class="d-flex lazy" data-original="/media/cache/e2/94/e294b5fd60e7384c3624c0ba340f9bd8.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Nepal Liquors
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/sales-officer-738/" title="Sales Officer - Apply Before: 1 week, 2 days from now">
# <span itemprop="title">
# Sales Officer
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Identify cu…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/product-manager-59/" title="Product Manager - Apply Before: 1 week, 2 days from now">
# <span itemprop="title">
# Product Manager
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Ability to …" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Upper Solu Hydro Electric Company" itemprop="name"/>
# <img alt="Upper Solu Hydro Electric Company" class="d-flex lazy" data-original="/media/cache/52/46/52464d714b0561e430f3ff972f17a4ff.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Upper Solu Hydro Electri…
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/general-manager-296/" title="General Manager - Apply Before: 6 days, 10 hours from now">
# <span itemprop="title">
# General Manager
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;p&gt;GM will be respo…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Deloitte" itemprop="name"/>
# <img alt="Deloitte" class="d-flex lazy" data-original="/media/cache/9a/4f/9a4f910dac533481116d56812341cbc1.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Deloitte
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/objective-1-lead-public-financial-management-expert-3/" title="Objective 1 Lead (Public Financial Management Expert) - Apply Before: 2 weeks from now">
# <span itemprop="title">
# Objective 1 Lead (Public …
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content='&lt;p align="center"&gt;&lt;…' itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/objective-2-lead-public-financial-management-expert/" title="Objective 2 Lead (Public Financial Management Expert) - Apply Before: 2 weeks from now">
# <span itemprop="title">
# Objective 2 Lead (Public …
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content='&lt;p align="center"&gt;&lt;…' itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Ultimate Business Advisors" itemprop="name"/>
# <img alt="Ultimate Business Advisors" class="d-flex lazy" data-original="/media/cache/63/eb/63ebd40f8d01061647b90a7a1a462a1c.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Ultimate Business Adviso…
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/audit-manager-12/" title="Audit Manager - Apply Before: 4 days, 10 hours from now">
# <span itemprop="title">
# Audit Manager
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Good knowle…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Shailung Group of Companies" itemprop="name"/>
# <img alt="Shailung Group of Companies" class="d-flex lazy" data-original="/media/cache/0a/82/0a823a4fca7b267c3993c144e8f08beb.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Shailung Group of Compan…
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/business-development-manager-345/" title="Business Development Manager - Apply Before: 1 week, 5 days from now">
# <span itemprop="title">
# Business Development Mana…
# </span>
# <meta content="2022-11-23" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;&lt;span&gt;Conta…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Innovate Nepal Group" itemprop="name"/>
# <img alt="Innovate Nepal Group" class="d-flex lazy" data-original="/media/cache/2a/ba/2aba136746bb24cc5d3dacb8f8df44e0.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Innovate Nepal Group
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/lecturers-35/" title="Lecturers - Apply Before: 3 days, 10 hours from now">
# <span itemprop="title">
# Lecturers
#
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;strong&gt;A. Modul…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Keystone Global Network" itemprop="name"/>
# <img alt="Keystone Global Network" class="d-flex lazy" data-original="/media/cache/c6/4b/c64bd61cadc549afbc046995ce2c3760.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Keystone Global Network
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/study-abroad-counsellor-usa/" title="Study Abroad Counsellor- USA - Apply Before: 1 week, 2 days from now">
# <span itemprop="title">
# Study Abroad Counsellor- …
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Providing o…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/graphic-designer-1071/" title="Graphic Designer - Apply Before: 1 week, 2 days from now">
# <span itemprop="title">
# Graphic Designer
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Developing …" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Caritas Nepal" itemprop="name"/>
# <img alt="Caritas Nepal" class="d-flex lazy" data-original="/media/cache/2a/53/2a5376bde647705c48d16ee9bbbed589.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Caritas Nepal
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/finance-officer-334/" title="Admin and Finance Officer - Apply Before: 5 days, 2 hours from now">
# <span itemprop="title">
# Admin and Finance Officer
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="None" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class="has-multiple p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Hitachi Energy" itemprop="name"/>
# <img alt="Hitachi Energy" class="d-flex lazy" data-original="/media/cache/85/a4/85a44d8fd1e7ce83926f5e022ac8c9af.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Hitachi Energy
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/devops-engineer-58/" title="DevOps Engineer - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# DevOps Engineer
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;span&gt;DevOps Eng…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/software-engineer-php-js-mssql-2/" title="Software Engineer (PHP/ JS/ MSSQL) - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# Software Engineer (PHP/ J…
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;span&gt;The main p…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 job-list d-none">
# •
# <a class="job_title hover-primary" href="/software-quality-test-engineer-5/" title="Software Quality Test Engineer - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# Software Quality Test Eng…
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;span&gt;The main p…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 job-list d-none">
# •
# <a class="job_title hover-primary" href="/software-engineer-net-33/" title="Software Engineer (.NET) - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# Software Engineer (.NET)
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;span&gt;The main p…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# <h2 class="h6 mb-1 job-list d-none">
# •
# <a class="job_title hover-primary" href="/client-support-specialist-5/" title="Client Support Specialist - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# Client Support Specialist
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;span&gt;The main p…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# <div class="absolute-dropdown">
# <span class="float-right"><span class="icon-arrow-down job-card-dropdown"></span></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Kunal Flooring and Furnishing" itemprop="name"/>
# <img alt="Kunal Flooring and Furnishing" class="d-flex lazy" data-original="/media/cache/83/d6/83d6d354052db580b5eda6e666e3dba6.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Kunal Flooring and Furni…
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/sales-manager-442/" title="Sales Manager - Apply Before: 2 days, 10 hours from now">
# <span itemprop="title">
# Sales Manager
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Selling pro…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Khalti Digital Wallet" itemprop="name"/>
# <img alt="Khalti Digital Wallet" class="d-flex lazy" data-original="/media/cache/0e/a3/0ea3091fec9abb54661cf54f6be6c2fb.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Khalti Digital Wallet
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/junior-business-development-technical-support-2/" title="Junior Merchant Support - Apply Before: 1 week, 2 days from now">
# <span itemprop="title">
# Junior Merchant Support
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;strong&gt;Main Res…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="KPO and Company" itemprop="name"/>
# <img alt="KPO and Company" class="d-flex lazy" data-original="/media/cache/7c/eb/7cebb7be5371a1056033e16456e2ad7d.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# KPO and Company
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/web-content-writer-26/" title="Web Content Writer - Apply Before: 2 weeks from now">
# <span itemprop="title">
# Web Content Writer
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Creating us…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Teach For Nepal" itemprop="name"/>
# <img alt="Teach For Nepal" class="d-flex lazy" data-original="/media/cache/9d/fb/9dfbe0cf2e94a55a8c0535a9921881bb.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Teach For Nepal
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/fellowship-8/" title="Teach For Nepal Fellowship - Apply Before: 1 month, 1 week from now">
# <span itemprop="title">
# Teach For Nepal Fellowship
# </span>
# <meta content="2022-11-22" itemprop="datePosted"/>
# <meta content="None" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="R. B. Diamond Jewellers" itemprop="name"/>
# <img alt="R. B. Diamond Jewellers" class="d-flex lazy" data-original="/media/cache/b1/d2/b1d2eab2e0b8bc573f0a523e560fffb7.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# R. B. Diamond Jewellers
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/digital-marketing-specialist-44/" title="Digital Marketing Specialist - Apply Before: 2 days, 10 hours from now">
# <span itemprop="title">
# Digital Marketing Special…
# </span>
# <meta content="2022-11-21" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Develop opt…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Suroshani Holidays" itemprop="name"/>
# <img alt="Suroshani Holidays" class="d-flex lazy" data-original="/media/cache/44/3e/443ee630cab6c379a4b87e663c12fff1.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Suroshani Holidays
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/ticketing-head-inboundoutbound/" title="Ticketing Head ( Inbound/Outbound) - Apply Before: 3 days, 10 hours from now">
# <span itemprop="title">
# Ticketing Head ( Inbound/…
# </span>
# <meta content="2022-11-21" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;&lt;li&gt;Handling In…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Build Up Nepal" itemprop="name"/>
# <img alt="Build Up Nepal" class="d-flex lazy" data-original="/media/cache/db/04/db0455a3246467c45cada1983a2bb297.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Build Up Nepal
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/field-sales-and-business-developer/" title="Sales and Business Developer - Apply Before: 1 week from now">
# <span itemprop="title">
# Sales and Business Develo…
# </span>
# <meta content="2022-11-21" itemprop="datePosted"/>
# <meta content="&lt;p&gt;We are looking f…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row no-gutters hj-row">
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Hulas Steel Industries Limited" itemprop="name"/>
# <img alt="Hulas Steel Industries Limited" class="d-flex lazy" data-original="/media/cache/54/bc/54bcce3f0412f5b4c0e9facba6278971.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Hulas Steel Industries L…
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/head-of-department-quality-control-cold-rolling-mill-division-crm/" title="Head of Quality Control-Cold Rolling Mill Division (CRM) - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# Head of Quality Control-C…
# </span>
# <meta content="2022-11-21" itemprop="datePosted"/>
# <meta content="&lt;ul&gt;
#  &lt;li&gt;&lt;span&gt;Res…" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-right border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# <div class="border mr-2 mb-2" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Hitachi Energy" itemprop="name"/>
# <img alt="Hitachi Energy" class="d-flex lazy" data-original="/media/cache/80/66/8066d8a424d71a2cef2311ecd3c9d05f.jpg" height="60" itemprop="image" width="60"/>
# </div>
# <div class="media-body">
# <h2 class="h6 mb-1" itemprop="title" title="">
# Hitachi Energy
# </h2>
# <h2 class="h6 mb-1 ">
# •
# <a class="job_title hover-primary" href="/associate-site-reliability-engineer-2/" title="Associate Site Reliability Engineer - Apply Before: 1 week, 6 days from now">
# <span itemprop="title">
# Associate Site Reliabilit…
# </span>
# <meta content="2022-11-21" itemprop="datePosted"/>
# <meta content="&lt;p&gt;&lt;span&gt;Associate …" itemprop="description"/>
# <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
# <span class="address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# </span>
# </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 border-bottom job-card">
# <div class=" p-2">
# <div class="row no-gutters" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="media">
# ...
# </a>
# <div class="media-body">
# <h6 class="mb-0">
# <a href="/blog/what-can-i-do-if-i-forgot-my-merojob-password/" title="What can I do if I forgot my merojob password?">
# What can I do if I forgot my merojob passwor…
# </a>
# </h6>
# <i class="text-muted small">Total Views: 816</i>
# </div>
# </div>
# <div class="media mb-1">
# <a href="/blog/best-practices-for-conducting-an-exit-interview/">
# <img alt="Best practices for conducting an exit interview" class="d-flex mr-2 img-fluid border" src="/media/cache/34/5e/345e3e08dabea46d15f77d6c92f35645.jpg"/>
# <meta content="64" itemprop="width"/>
# <meta content="64" itemprop="height"/>
# </a>
# <div class="media-body">
# <h6 class="mb-0">
# <a href="/blog/best-practices-for-conducting-an-exit-interview/" title="Best practices for conducting an exit interview">
# Best practices for conducting an exit interv…
# </a>
# </h6>
# <i class="text-muted small">Total Views: 653</i>
# </div>
# </div>
# </div>
# <div class="card-footer p-2 m-0">
# <div class="float-right">
# <a class="small" href="/blog/">
# <span class="icon-preview mr-2"></span> View All
# </a>
# </div>
# </div>
# </div>
# </section>
# <div class="card text-center mt-3 height-overflow-x" id="div-gpt-ad-1578480082036-0">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1578480082036-0'); });
#               </script>
# </div>
# <div class="card text-center mt-3 height-overflow-x" id="div-gpt-ad-1578480154188-0">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1578480154188-0'); });
#               </script>
# </div>
# <div class="card text-center mt-3 height-overflow-x" id="div-gpt-ad-1578480233430-0">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1578480233430-0'); });
#               </script>
# </div>
# <section class="my-3" id="fb-section">
# <div class="fb-page" data-adapt-container-width="true" data-hide-cover="false" data-href="https://www.facebook.com/merojob/" data-show-facepile="true" data-small-header="false" data-tabs="timeline">
# <blockquote cite="https://www.facebook.com/merojob/" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/merojob/">MeroJob.Com</a></blockquote>
# </div>
# </section>
# </div>
# </div>
# </div>
# <section class="bg-secondary pt-3 mh-50">
# <div class="container">
# <div class="row">
# <div class="col-md-9 my-auto">
# <h4 class="text-white">
# <strong>Take Jobs in Pocket with you!</strong><br/>
# Stay updated with new jobs on the go<br/>
# with our official apps on Android and iOS.
# </h4>
# <div class="row">
# <div class="col-md-12">
# <a aria-label="Download Android App" class="btn py-0 px-0" href="https://play.google.com/store/apps/details?id=com.merojob.merojobapp" rel="noopener noreferrer" target="_blank">
# <img alt="Download Android App" class="my-3 lazy" data-original="https://static.merojob.com/images/mobile/google.png"/>
# </a>
# <a aria-label="Download iOS App" class="btn py-0 px-0" href="https://itunes.apple.com/us/app/merojob-com/id1301256298?mt=8" rel="noopener noreferrer" target="_blank">
# <img alt="Download iOS App" class="m-3 lazy" data-original="https://static.merojob.com/images/mobile/apple.png"/>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <img alt="Mobile" class="lazy" data-original="https://static.merojob.com/images/mobile/mobile.png"/>
# </div>
# </div>
# </div>
# </section>
# <section class="bg-white shadow d-md-block d-none" data-toggle="stickybottom-onscroll" id="buttomSlider">
# <div class="container py-3">
# <div class="row align-items-center">
# <div class="h5 col-md-4 offset-md-1 text-center text-md-right text-primary mb-3 mb-md-0">
# <span>Search, Apply &amp; Get Job: <span class="font-weight-bold">FREE</span></span>
# </div>
# <div class="col-6 col-md-2">
# <a class="btn bg-secondary animate-push border-radius-3 w-100 text-white" href="/jobseeker/register/">
# <span class="icon-user"></span> <span>REGISTER</span>
# </a>
# </div>
# <div class="col-6 col-md-2">
# <a class="btn btn-outline-secondary animate-push border-radius-3 w-100" href="/jobseeker/login/">
# <span class="icon-password"></span> <span>LOGIN</span>
# </a>
# </div>
# <div class="col-md-3 text-left text-md-center pt-3 pt-md-0">
# <a class="w-100" href="/employer-zone/">
# <span class="icon-building mr-2"></span> <span>Are You an Employer?</span>
# </a>
# </div>
# </div>
# </div>
# </section>
# <div class=" footer d-print-none">
# <div class="swatch-700">
# <div class="container py-4 text-white-50">
# <div class="row">
# <div class="col-md-4">
# <p class="small text-justify">
# Since inception in 2009, we have turned out to be number one jobs provider in Nepal with 300
# million+ page views so far and 6.5 million+ progressive visits every month, created 2,00,000+ success stories
# and registered 7,50,000+ job seekers in our database. We have been offering 35,000+ employers
# promote their employer brands to jobseekers and advertise diverse opportunities to over a million
# candidates inside Nepal and abroad. Established as an inevitable bridge between the hiring employers
# and the job seekers, we are well-known as a national leader in recruitment solutions &amp; career
# management in Nepal. <a class="text-secondary" href="/about-us/" target="_blank">Read more...</a>
# </p>
# </div>
# <div class="col-md-2">
# <h6 class="text-white">FOR JOBSEEKER</h6>
# <ul class="list-unstyled">
# <li>
# <a class="text-white-50" href="/jobseeker/register/"> Register</a>
# </li>
# <li>
# <a class="text-white-50" href="/search/"> Search Jobs</a>
# </li>
# <li>
# <a class="text-white-50" href="/jobseeker/login/"> Login</a>
# </li>
# <li>
# <a class="text-white-50" href="/blog/"> Blog</a>
# </li>
# <li>
# <a class="text-white-50" href="/faq/"> FAQ</a>
# </li>
# </ul>
# </div>
# <div class="col-md-2">
# <h6 class="text-white">FOR EMPLOYER</h6>
# <ul class="list-unstyled">
# <li><a class="text-white-50" href="/employer-zone/">Post a
# Job</a></li>
# <li><a class="text-white-50" href="/employer/register/">Register</a>
# </li>
# <li><a class="text-white-50" href="/employer/login/">Login</a>
# </li>
# <li><a class="text-white-50" href="/recruitment-services/">Recruitment
# Services</a></li>
# <li><a class="text-white-50" href="/blog/category/hr-insider/">HR Insider</a></li>
# <li><a class="text-white-50" href="/faq/">FAQ</a></li>
# </ul>
# </div>
# <div class="col-md-2">
# <h6 class="text-white">ABOUT US</h6>
# <ul class="list-unstyled">
# <li><a class="text-white-50" href="/about-us/" target="_blank">About
# merojob</a></li>
# <li><a class="text-white-50" href="/career-in-merojob/" target="_blank">Life
# at merojob</a></li>
# <li><a class="text-white-50" href="https://www.facebook.com/merojob/" rel="noopener noreferrer" target="_blank">Facebook</a></li>
# <li><a class="text-white-50" href="https://twitter.com/merojob/" rel="noopener noreferrer" target="_blank">Twitter</a></li>
# <li><a class="text-white-50" href="https://www.linkedin.com/company/707051" rel="noopener noreferrer" target="_blank">LinkedIn</a></li>
# <li><a class="text-white-50" href="/contact/" target="_blank">Feedback</a>
# </li>
# </ul>
# </div>
# <div class="col-md-2">
# <h6 class="text-white">CONTACT US</h6>
# <div class="media">
# <div class="media-left">
# <span class="icon-pin mr-2"></span>
# </div>
# <div class="media-body">
# <p class="text-white-50 mb-1">
# Ganapati Bhawan<br/>Min Bhawan Main Road<br/>New
# Baneshwor<br/>Kathmandu, Nepal
# </p>
# </div>
# </div>
# <div class="media">
# <div class="media-left">
# <span class="icon-call mr-2"></span>
# </div>
# <div class="media-body">
# <a class="text-white-50 mb-1 mt-1" href="tel:+977-01-4106701">+977 1 4106701</a><br/>
# <a class="text-white-50 mb-1 mt-1" href="tel:+977-01-4106700">+977 1 4106700</a>
# </div>
# </div>
# <div class="media">
# <div class="media-left">
# <span class="icon-email mr-2"></span>
# </div>
# <div class="media-body">
# <a class="text-white-50" href="/cdn-cgi/l/email-protection#6e070008012e030b1c0104010c400d0103"><span class="__cf_email__" data-cfemail="c8a1a6aea788a5adbaa7a2a7aae6aba7a5">[email protected]</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class=" footer-sub swatch-800 pt-2 pb-2">
# <div class="container text-white-50">
# <div class="text-center max-h-0">
# <div class="mx-auto footer-arc">
# <a class="p-2" href="/">
# <img alt="merojob.com" class="footer-brand-logo mb-2 lazy mt-3" src="https://static.merojob.com/images/logo/svg/mj_logo_icon_white.svg" style="width: 3rem;"/>
# </a>
# </div>
# </div>
# </div>
# <div class="container text-white-50 mt-md-0 mt-sm-4 mt-4 ">
# <div class="row pt-2 pb-2 text-md-left text-center">
# <div class="col-md-5 col-sm-12 col-12">
# <a aria-label="Facebook" class="text-white-50 mx-1 facebook-ico" href="https://www.facebook.com/merojob/" rel="nofollow noopener noreferrer" target="_blank">
# <span class="icon-facebook icon-one-half-x"></span>
# </a>
# <a aria-label="Twitter" class="text-white-50 mx-1 twitter-ico" href="https://twitter.com/merojob" rel="nofollow noopener noreferrer" target="_blank">
# <span class="icon-twitter icon-one-half-x"></span>
# </a>
# <a aria-label="YouTube" class="text-white-50 mx-1 youtube-ico" href="https://www.youtube.com/user/meroJobDotCom" rel="nofollow noopener noreferrer" target="_blank">
# <span class="icon-youtube icon-one-half-x"></span>
# </a>
# <a aria-label="LinkedIn" class="text-white-50 mx-1 linkedin-ico" href="https://www.linkedin.com/company/merojob" rel="nofollow noopener noreferrer" target="_blank">
# <span class="icon-linkedin icon-one-half-x"></span>
# </a>
# <a aria-label="Android Play Store" class="text-white-50 mx-1" href="https://play.google.com/store/apps/details?id=com.merojob.merojobapp" rel="nofollow noopener noreferrer" target="_blank">
# <span class="icon-android icon-one-half-x"></span>
# </a>
# <a aria-label="Apple App Store" class="text-white-50 mx-1" href="https://apps.apple.com/us/app/merojob-com/id1301256298" rel="nofollow noopener noreferrer" target="_blank">
# <span class="icon-apple icon-one-half-x"></span>
# </a>
# </div>
# <ul class="col-md-7 col-sm-12 col-12 text-md-right">
# <li class="list-inline-item">
# <a class="text-white-50" href="/terms-and-conditions/">Terms</a>
# </li>
# |
# <li class="list-inline-item">
# <a class="text-white-50" href="/privacy-policy/">Privacy</a>
# </li>
# |
# <li class="list-inline-item">
# © 2022 All Rights with <a class="text-secondary" href="https://merojob.com/">merojob</a>
# </li>
# </ul>
# </div>
# </div>
# <div aria-hidden="true" class="modal" id="generic-modal-box" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# </div>
# </div>
# </div>
# <div aria-hidden="true" class="modal" id="generic-modal-large-box" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-lg">
# <div class="modal-content">
# </div>
# </div>
# </div>
# <div aria-hidden="true" class="modal" id="generic-modal-small-box" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-sm">
# <div class="modal-content">
# </div>
# </div>
# </div>
# <button class="btn swatch-600 btn-sm back-to-top" data-placement="left" data-toggle="tooltip" id="back-to-top" title="Click to return on the top page">
# <span class="icon-arrow-up"></span>
# </button>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script>
#   (function (i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function () {
#       (i[r].q = i[r].q || []).push(arguments)
#     }, i[r].l = 1 * new Date();
#     a = s.createElement(o),
#       m = s.getElementsByTagName(o)[0];
#     a.async = 1;
#     a.src = g;
#     m.parentNode.insertBefore(a, m)
#   })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#   ga('create', 'UA-3260078-1', 'merojob.com');
#   ga('send', 'pageview');
#
# </script>
# <script type="text/javascript">var sc_project = 3203895;
# var sc_invisible = 1;
# var sc_security = "99698840";
# var scJsHost = (("https:" == document.location.protocol) ? "https://secure." : "http://www.");
# document.write("<sc" + "ript type='text/javascript' src='" + scJsHost + "statcounter.com/counter/counter.js'></" + "script>");</script>
# <noscript>
# <div class="statcounter"><a href="http://statcounter.com/" target="_blank" title="website
#     statistics"><img alt="website
#     statistics" class="statcounter" data-pagespeed-url-hash="1068854636" src="//c.statcounter.com/3203895/0/99698840/1/"/></a></div>
# </noscript>
# <span class="no-display" id="page-identifier">landing_page</span>
# <span class="no-display" id="csrf-ad"><input name="csrfmiddlewaretoken" type="hidden" value="kviQljWGecejyqCd5muc7mElPYNDtA46tfCfpEeRiXmtIde2p8rP8FmzFtGvEKtA"/></span>
# <script src="https://static.merojob.com/dist/main-4fb3c46a2616c83d69c9.bundle.js" type="text/javascript"></script>
# <script src="https://static.merojob.com/js/landing.js"></script>
# <script src="https://static.merojob.com/js/stickybottomToggle.js"></script>
# <script type="text/javascript">
#     $(function () {
#         $("img.lazy").lazyload();
#     });
#
# </script>
# <div id="fb-root"></div>
# <script>
#     function loadFb() {
#         (function (d, s, id) {
#             var js, fjs = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) return;
#             js = d.createElement(s);
#             js.id = id;
#             js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.10&appId=230516776988241";
#             fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#     }
#     $(window).scroll(function () {
#         const $height = $(window).scrollTop();
#         if ($height >= $("#fb-section").position().top) {
#             loadFb()
#         }
#     });
# </script>
# <script>
#     // hide extended job card on click down arrow
#     $('#actively-seeking').click(function (){
#         $('#covid-response').modal('show')
#     });
#
#     $(".job-card-dropdown").click(function () {
#         const par = $(this).parents(".has-multiple");
#         if (par.hasClass('zoom')) {
#             par.removeClass('zoom');
#             par.find('.job-list').addClass('d-none');
#         } else {
#             par.addClass('zoom');
#             par.find('.job-list').removeClass('d-none');
#         }
#     })
# </script>
# <script>
#     const STATIC_URL = "https://static.merojob.com/";
#
#     function getCsrf() {
#         token = "kviQljWGecejyqCd5muc7mElPYNDtA46tfCfpEeRiXmtIde2p8rP8FmzFtGvEKtA";
#         return token;
#     }
#     $(document).ready(function (){
#         let currentTimestamp = Date.now();
#         $('#close-nav-ad').click(function (){
#             localStorage.setItem("last-showed-at", currentTimestamp);
#         })
#     });
# </script>
# <script src="https://static.merojob.com/dist/notice-4fb3c46a2616c83d69c9.bundle.js" type="text/javascript"></script>
# <link href="https://static.merojob.com/fonts/style-0LPQbbs222l2ywx.css" media="none" onload="if(media!='all')media='all'" rel="stylesheet">
# <script>(function(){var js = "window['__CF$cv$params']={r:'76e8b661383122e8',m:'88usWB7Lf2v.VrlRRyGfDdApC53ZFG6KWkEPaGOsQ94-1669194005-0-Af/fkpCvYF7FGZsqBtuEtsXM64eoi8vquqgm/CXE79DBmShOzhTpxudYB9ZtLpzf/pyt7VuoUhidostIFdcM4S/X7G10GECZ+hOnaAD9Y3GD3Eh2uhY1b7wYe0stNnbWZw==',s:[0x5308171cab,0xb8478adbd3],u:'/cdn-cgi/challenge-platform/h/b'};var now=Date.now()/1000,offset=14400,ts=''+(Math.floor(now)-Math.floor(now%offset)),_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/h/b/scripts/alpha/invisible.js?ts='+ts,document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></link></div></div></div></body>
# </html>
# >
